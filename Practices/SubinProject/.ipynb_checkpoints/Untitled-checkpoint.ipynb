# %%
# 작성자 : 이민우
# 작성일 : 20181119 ~ 
# 프로그램설명 : 머신러닝을 이용한 날씨 및 미세머지와 외출의 관계 예측
import os
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedShuffleSplit

import datetime

import warnings

warnings.filterwarnings('ignore')


    
def load_xlsx_data(filename, test_path = "datasets"): # 주어진 filename 을 읽는 함수
    xlsx_path = os.path.join(test_path,filename)
    return pd.read_excel(xlsx_path)

if __name__ == "__main__":
     
    basic = load_xlsx_data("기초생활.xls")
    lonely = load_xlsx_data("독거노인.xls")
    cost = load_xlsx_data("부양비 노령화.xls")
    reson = load_xlsx_data("사망원인.xls")
    cancer = load_xlsx_data("암.xls")
    suicide = load_xlsx_data("자살률.xls")
    
    cnt = 0
    for i in basic:
        if cnt != 1 and cnt != 4:
            basic = basic.drop(i,axis = 1)
        cnt = cnt + 1
        
    
    #print(basic.info())
    
    
    cnt = 0
    for i in lonely:
        if cnt != 1 and cnt != 2 and cnt != 5 and cnt != 8 and cnt != 11:
            lonely = lonely.drop(i,axis = 1)
        cnt = cnt + 1
    
    
    cnt = 0
    for i in reson:
        if cnt != 1 and cnt != 17 :
            reson = reson.drop(i,axis = 1)
        cnt = cnt + 1
        
         
    cnt = 0
    for i in cancer:
        if cnt != 1 and cnt != 2 :
            cancer = cancer.drop(i,axis = 1)
        cnt = cnt + 1
        
    cnt = 0
    for i in suicide:
        if cnt != 1  and cnt != 5 :
            suicide = suicide.drop(i,axis = 1)
        cnt = cnt + 1
    
    
   
    
    suicide_set = pd.DataFrame(columns = ("구","자살률","기초생활수급자","독거노인 수","국민기초생활보장수급자(독거노인)",
                                          "저소득노인(독거노인)","일반독거노인","정신병사망인원","암사망인원"))
    
    
    basic = basic.drop(0,0)
    basic = basic.drop(1,0)
    basic = basic.drop(3,0)
    lonely = lonely.drop(0,0)
    lonely = lonely.drop(1,0)
    reson = reson.drop(0,0)
    cancer = cancer.drop(0,0)
    cancer = cancer.drop(1,0)
    suicide = suicide.drop(0,0)
  
    for i in range(26):
        li = [ basic.iloc[i][0], suicide.iloc[i][1], basic.iloc[i][1], lonely.iloc[i][1], lonely.iloc[i][2],
              lonely.iloc[i][3], lonely.iloc[i][4], reson.iloc[i][1], cancer.iloc[i][1] ]
        suicide_set.loc[len(suicide_set)] = li
    
    print(suicide_set)
    corr_matrix = suicide_set.corr()
    print(corr_matrix)
    #print(corr_matrix["자살률"].sort_values(ascending = False))
# Out:
#        구   자살률 기초생활수급자  독거노인 수 국민기초생활보장수급자(독거노인) 저소득노인(독거노인)  일반독거노인 정신병사망인원  \
# 0     합계  21.3  264227  303824             59772       18664  225388     646
# 1    종로구  30.4    4296    7394              1256         344    5794      10
# 2     중구  22.3    3966    5725              1112         286    4327      13
# 3    용산구  23.7    5940    8664              2052         403    6209      21
# 4    성동구  22.6    7003    9508              1501         664    7343      23
# 5    광진구  20.2    7411    9711              1506         732    7473      20
# 6   동대문구  18.5   11300   15355              7300         276    7779      31
# 7    중랑구  26.0   15228   12674              3047        1019    8608      28
# 8    성북구  21.9   12434   14082              2529         841   10712      29
# 9    강북구  26.3   14953   14759              3109        1511   10139      16
# 10   도봉구  28.7   10625   11328              1647         897    8784      31
# ...
